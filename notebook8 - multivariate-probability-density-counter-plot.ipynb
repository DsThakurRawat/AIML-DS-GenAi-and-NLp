# %%
""""🔷 What is Multivariate Probability?
✅ Definition:
Multivariate probability deals with the probability distribution of two or more random variables occurring together. It extends the concept of univariate (one variable) and bivariate (two variables) probability to multiple variables.

📌 Examples:
Joint Probability Distribution:

𝑃
(
𝑋
=
𝑥
,
𝑌
=
𝑦
)
P(X=x,Y=y): Probability that X = x AND Y = y.

For example: 
𝑃
(
rain
=
yes
,
traffic
=
high
)
P(rain=yes,traffic=high)

Multivariate Normal Distribution:

A generalization of the normal (Gaussian) distribution for multiple variables.

Each variable is normally distributed, and their joint behavior is modeled by a covariance matrix.

🔧 Real Use Cases:
Predicting outcomes involving several variables (like stock prices, weather models).

Multivariate statistics in machine learning (e.g., Naive Bayes, Gaussian Mixture Models).

Joint analysis of sensor data.
""""

# %%
""""
🔷 What is a Contour Plot?
✅ Definition:
A contour plot is a graphical technique for representing a 3D surface on a 2D plane, using contour lines. Each contour line represents points of equal value (like height, temperature, or probability density).

It is often used to visualize multivariate functions of the form:

𝑍
=
𝑓
(
𝑋
,
𝑌
)
Z=f(X,Y)
where X and Y are input variables and Z is the output.


""""

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import multivariate_normal

# Define grid
x = np.linspace(-3, 3, 100)
y = np.linspace(-3, 3, 100)
X, Y = np.meshgrid(x, y)

# Mean and covariance matrix
mu = [0, 0]
sigma = [[1, 0.5], [0.5, 1]]

# Compute the multivariate normal PDF
pos = np.dstack((X, Y))
rv = multivariate_normal(mu, sigma)
Z = rv.pdf(pos)

# Contour Plot
plt.figure(figsize=(6,5))
contour = plt.contour(X, Y, Z, levels=10, cmap='viridis')
plt.colorbar(contour)
plt.title("Contour Plot of 2D Gaussian Distribution")
plt.xlabel("X")
plt.ylabel("Y")
plt.show()

# %%
""""🔧 Where is it used?
Visualizing joint distributions of two variables.

Heatmaps for probability densities.

In optimization, to show objective functions in machine learning.

Meteorology (e.g., pressure maps), physics (e.g., potential fields).
"""""

# %%
| Term                     | Description                                                              |
| ------------------------ | ------------------------------------------------------------------------ |
| Multivariate Probability | Probability involving multiple random variables                          |
| Contour Plot             | A 2D plot showing equal-value lines for a 3D surface (e.g., probability) |
